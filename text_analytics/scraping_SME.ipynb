# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time

# %%
class ScrapeSME:
    def __init__(self):
        # Base soup object
        self.page = requests.get("http://www.sme.sk")
        self.soup = BeautifulSoup(self.page.content, 'html.parser')
        
        # I will be adding links here constantly so needs to be class variable
        # loading old links from disk
        try:
            self.scraped_links = list(pd.read_csv(data_path + "sme_links.csv", sep = "|").links.values)
            print len(self.scraped_links), "links loaded from disk"
        except IOError:    
            # Empty link list if no data are on the disk
            self.scraped_links = []
        self.scraped_links = []
    
    def find_body(self, soup = None):
        if soup is None:
            soup = self.soup
        main_content = list(soup.children)
        for i in main_content:
            #ked zacina cast <html tak to je main part
            if str(i).find("<html") == 0:
                inner_content = i
                for j in inner_content:
                    if str(j).find("<body") == 0:
                        body = j
                        print "Find HTML <body>: Successfull!!"
        if 'body' not in locals():
            print "body wasn't find"
            body = None
        return body
    
    def find_initial_links(self):
        article_links = []
        summaries = []
        body = self.find_body()
        for i in body.select('div.col-responsive div a.js-smphr-item'):
            link = str(i.get("href"))
            if link.find("?") != -1:
                link = link[:link.find("?")]
            summaries.append(i.get_text())
            article_links.append(link)
    
        return article_links, summaries
            
    def scrape(self):
        # initial links to scrape
        article_links, summaries = self.find_initial_links()
        self.sme_articles = {}
        i = 0
        while i < len(article_links):
            print "Number of articles for download:",len(article_links)
            print "Scraping article number", i+1
            link = article_links[i]
            print link
            summary = summaries[i]
            # skip this interation if link is already parsed
            if link in self.scraped_links:
                print "Link already scraped, skipping...!"
                print ""
                i = i + 1
                continue
            
            # sometimes link doesn't work
            try:
                article = requests.get(link)
            except:
                print "link was corrupted"
                print ""
                i = i + 1
                # skips rest of the loop
                continue
            
            local_soup = BeautifulSoup(article.content, 'html.parser')
            # find HTML <body> tag
            body = self.find_body(soup = local_soup)
            if body == None:
                print "link was corrupted"
                print ""
                i = i + 1
                # skips rest of the loop
                continue
            # label is group of news from webpage
            label = re.search('//(.*).sme.sk', link).group(1)
            text = ""
            # identification of text of the article
            for article_part in body.select('article p'):
                 text = text + "\n" + article_part.get_text()
            self.sme_articles[i] = (label,summary, text)
            
            #identification of next articles:
            for next_article in body.select('div.media-body h2.media-heading a'):
                # getting new links from current article
                new_link = str(next_article.get("href"))
                # sometimes, there is a source page after the "?" leading to duplicates in the link
                if new_link.find("?") != -1:
                    # removing part after the "?"
                    new_link = new_link[:new_link.find("?")]
                new_summary = next_article.get_text()
                # if new_link is not in the list, then it will be added
                if new_link not in article_links:
                    article_links.append(new_link)
                    summaries.append(new_summary)
                    
            #identification of next articles:
            for next_article in body.select('div.cr-box div.cr-content h4 a'):
                new_link = str(next_article.get("href"))
                if new_link.find("?") != -1:
                    new_link = new_link[:new_link.find("?")]
                new_summary = next_article.get_text()
                if new_link not in article_links:
                    article_links.append(new_link)
                    summaries.append(new_summary)
            
            i = i + 1
            self.scraped_links.append(link)
            print "Done!!"
            print ""
            
            # Saving to disk temp results
            if (i%100 == 0) & (len(self.sme_articles) > 1):
                print "Saving partial results to disk!"
                df_articles = pd.DataFrame(self.sme_articles).transpose()
                df_articles.columns = ["label","summary","text"]
                df_articles.to_csv(data_path + "temp_sme_articles.csv", sep = "|", index=False, encoding="utf-8")
                df_links = pd.DataFrame(self.scraped_links)
                df_links.columns = ["links"]
                df_links.to_csv(data_path + "temp_sme_links.csv", sep = "|", index=False, encoding="utf-8")
        
        # Creating final dataframe and saving to disk
        # TODO better savings
        if len(self.sme_articles) > 0:
            postfix = str(time.time())
            if postfix.find(".") != -1:
                postfix = postfix[:postfix.find(".")]
            
            print "Saving final results to disk!"
            df_articles = pd.DataFrame(self.sme_articles).transpose()
            df_articles.columns = ["label","summary","text"]
            df_articles.to_csv(data_path + "sme_articles"+ postfix + ".csv", sep = "|", index=False, encoding="utf-8")
            df_links = pd.DataFrame(self.scraped_links)
            df_links.columns = ["links"]
            df_links.to_csv(data_path + "sme_links.csv", sep = "|", index=False, encoding="utf-8")
        else:
            print "No new articles scraped"
        return self.sme_articles, self.scraped_links

# %%
# x = ScrapeSME()
# articles, links = x.scrape()

# %%
data_path = "/Users/jurajkapasny/Data/sk_text_for_api/"

# %%
if __name__ == '__main__':
    start_time = time.time()
    scraper = ScrapeSME()
    articles, links = scraper.scrape()
    end_time = time.time()
    elapsed = end_time - start_time
    minutes = int(elapsed / 60)
    seconds = elapsed % 60
    print "Number of scraped articles:", len(articles)
    print "Time Elapsed:", minutes, "minutes and", seconds, "seconds"
    print "================================="
    print ""
# Out:
# Find HTML <body>: Successfull!!
# Number of articles for download: 8
# Scraping article number 1
# Find HTML <body>: Successfull!!
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 13
# Scraping article number 2
# Find HTML <body>: Successfull!!
# Done!!
#
# Number of articles for download: 13
# Scraping article number 3
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 20
# Scraping article number 4
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 20
# Scraping article number 5
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 23
# Scraping article number 6
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 23
# Scraping article number 7
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 25
# Scraping article number 8
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 25
# Scraping article number 9
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 29
# Scraping article number 10
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 29
# Scraping article number 11
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 29
# Scraping article number 12
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 29
# Scraping article number 13
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 49
# Scraping article number 14
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 49
# Scraping article number 15
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 49
# Scraping article number 16
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 17
# Find HTML <body>: Successfull!!
# Done!!
#
# Number of articles for download: 53
# Scraping article number 18
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 19
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 20
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 21
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 22
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 23
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 24
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 25
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 26
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 27
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 28
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 29
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 53
# Scraping article number 30
# link was corrupted
#
# Number of articles for download: 53
# Scraping article number 31
# link was corrupted
#
# Number of articles for download: 53
# Scraping article number 32
# link was corrupted
#
# Number of articles for download: 53
# Scraping article number 33
# link was corrupted
#
# Number of articles for download: 53
# Scraping article number 34
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 57
# Scraping article number 35
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 57
# Scraping article number 36
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 57
# Scraping article number 37
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 57
# Scraping article number 38
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 57
# Scraping article number 39
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 61
# Scraping article number 40
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 71
# Scraping article number 41
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 84
# Scraping article number 42
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 84
# Scraping article number 43
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 91
# Scraping article number 44
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 93
# Scraping article number 45
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 46
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 47
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 48
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 49
# Find HTML <body>: Successfull!!
# Done!!
#
# Number of articles for download: 93
# Scraping article number 50
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 51
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 52
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 53
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# yyy
# yyy
# yyy
# yyy
# yyy
# Done!!
#
# Number of articles for download: 93
# Scraping article number 54
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 93
# Scraping article number 55
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 93
# Scraping article number 56
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 95
# Scraping article number 57
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 95
# Scraping article number 58
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 59
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 60
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 61
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 62
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 63
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 64
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 65
# link was corrupted
#
# Number of articles for download: 95
# Scraping article number 66
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 98
# Scraping article number 67
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 98
# Scraping article number 68
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 98
# Scraping article number 69
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 98
# Scraping article number 70
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 98
# Scraping article number 71
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 109
# Scraping article number 72
# link was corrupted
#
# Number of articles for download: 109
# Scraping article number 73
# link was corrupted
#
# Number of articles for download: 109
# Scraping article number 74
# link was corrupted
#
# Number of articles for download: 109
# Scraping article number 75
# link was corrupted
#
# Number of articles for download: 109
# Scraping article number 76
# Find HTML <body>: Successfull!!
# Done!!
#
# Number of articles for download: 109
# Scraping article number 77
# Find HTML <body>: Successfull!!
# Done!!
#
# Number of articles for download: 109
# Scraping article number 78
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 113
# Scraping article number 79
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 113
# Scraping article number 80
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 113
# Scraping article number 81
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 118
# Scraping article number 82
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 118
# Scraping article number 83
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 118
# Scraping article number 84
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 118
# Scraping article number 85
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 123
# Scraping article number 86
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 123
# Scraping article number 87
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 128
# Scraping article number 88
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 128
# Scraping article number 89
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 128
# Scraping article number 90
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 132
# Scraping article number 91
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 140
# Scraping article number 92
# Find HTML <body>: Successfull!!
# Done!!
#
# Number of articles for download: 140
# Scraping article number 93
# Find HTML <body>: Successfull!!
# Done!!
#
# Number of articles for download: 140
# Scraping article number 94
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 140
# Scraping article number 95
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 141
# Scraping article number 96
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 141
# Scraping article number 97
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 141
# Scraping article number 98
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 143
# Scraping article number 99
# link was corrupted
#
# Number of articles for download: 143
# Scraping article number 100
# link was corrupted
#
# Number of articles for download: 143
# Scraping article number 101
# link was corrupted
#
# Number of articles for download: 143
# Scraping article number 102
# link was corrupted
#
# Number of articles for download: 143
# Scraping article number 103
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 147
# Scraping article number 104
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 147
# Scraping article number 105
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 147
# Scraping article number 106
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 147
# Scraping article number 107
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 151
# Scraping article number 108
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 155
# Scraping article number 109
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 155
# Scraping article number 110
# link was corrupted
#
# Number of articles for download: 155
# Scraping article number 111
# link was corrupted
#
# Number of articles for download: 155
# Scraping article number 112
# link was corrupted
#
# Number of articles for download: 155
# Scraping article number 113
# link was corrupted
#
# Number of articles for download: 155
# Scraping article number 114
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 159
# Scraping article number 115
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 159
# Scraping article number 116
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 159
# Scraping article number 117
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 166
# Scraping article number 118
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 172
# Scraping article number 119
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 172
# Scraping article number 120
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 172
# Scraping article number 121
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 172
# Scraping article number 122
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 173
# Scraping article number 123
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 174
# Scraping article number 124
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 125
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 126
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 127
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 128
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: 174
# Scraping article number 129
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 130
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 131
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 132
# link was corrupted
#
# Number of articles for download: 174
# Scraping article number 133
# Find HTML <body>: Successfull!!
# xxx
# xxx
# Done!!
#
# Number of articles for download: 176
# Scraping article number 134
# Find HTML <body>: Successfull!!
# xxx
# xxx
# Done!!
#
# Number of articles for download: 176
# Scraping article number 135
# Find HTML <body>: Successfull!!
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# xxx
# Done!!
#
# Number of articles for download: